# %%
import pandas as pd
import numpy as np

from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn import preprocessing

from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
enc = preprocessing.OneHotEncoder()



from keras.layers import Input, Dense
from keras import regularizers

from tensorflow.keras import Model
from tensorflow.keras import Sequential
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError



from keras.models import Model
from keras.layers import Input, Dense
from keras import regularizers
from keras.layers import LSTM


from dask import dataframe as dd 

from xgboost import XGBRegressor

import snowflake.connector

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score


from sklearn.preprocessing import MinMaxScaler
from sklearn.inspection import permutation_importance
import seaborn as sns 
from matplotlib import pyplot as plt

import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual



#Classifier imports
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.linear_model import Ridge 
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
from ipywidgets import interact, Dropdown
from IPython.html import widgets
from IPython.display import display
import panel as pn
pn.extension()
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\html.py:12: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   warn("The `IPython.html` package has been deprecated since IPython 4.0. "
# <style>.container { width:75% !important; }</style>

# %%
conn = snowflake.connector.connect( user = 'sam winter', password = 'Mas1wint', account = 'oe73222.eu-west-2.aws', database = 'SAELSFORCE', schema = 'TEST' )

cs = cur = conn.cursor()

allrows=cs.execute("SELECT * FROM  DEPLAYPEN.SALESFORCEPOC.PROCESSEDSALESFORCE").fetchall()
                 #  WILMDIVISION,WILMORGNAME, CLIENTORG, OPPORTUNITYNAME, STAGENAME, TYPE, FISCALQUARTER, AMOUNT, REVENUE, UNITPRICE, CREDITNOTETOTAL , CREATEDATE, CLOSEDATE, PIPETIME, PIPETIMED, TIMEVAL, CREDITVAL FROM DEPLAYPEN.SALESFORCEPOC.SALESFORCESCALED  ").fetchall()

bas = pd.DataFrame(allrows)

#bas = bas.drop_duplicates()

# %%
bas.columns = ['WILMDIVISION','WILMORGNAME','WILMORGNAMECODE','CLIENTORG','OPPORTUNITYNAME','STAGENAME','PRODUCTNAME','FISCALQUARTER','TYPE','CREATEDDATE','CLOSEDATE','AMOUNT','CREDITNOTETOTAL','REVENUE','COST','UNITPRICE','CLOSEDT','PIPETIME','PIPETIMED','TIMEVAL','CREDITVAL','WILMORGNAMECODELE','CLIENTORGLE','OPPORTUNITYNAMELE','PRODUCTNAMELE','STAGENAMELE','FISCALQUARTERLE','TYPELE','CREATEDDATELE','CLOSEDTLE','PIPETIMELE','WILMDIVISIONLE','WILMORGNAMELE','AMOUNTSCALED','CREDITNOTETOTALSCALED','REVENUESCALED','COSTSCALED','UNITPRICESCALED','PIPETIMEDSCALED','TIMEVALSCALED','CREDITVALSCALED','CNLABEL','CLUSTER','CLUSTERCAT']

# %%
bas
# Out:
#             WILMDIVISION                                 WILMORGNAME  \
# 0      Risk & Compliance                 ICA Commercial Services Ltd
# 1      Risk & Compliance                 ICA Commercial Services Ltd
# 2      Risk & Compliance  International Compliance Association (ICA)
# 3      Risk & Compliance  International Compliance Association (ICA)
# 4      Risk & Compliance  International Compliance Association (ICA)
# ...                  ...                                         ...
# 47603  Risk & Compliance  International Compliance Association (ICA)
# 47604  Risk & Compliance  International Compliance Association (ICA)
# 47605  Risk & Compliance  International Compliance Association (ICA)
# 47606  Risk & Compliance  International Compliance Association (ICA)
# 47607  Risk & Compliance  International Compliance Association (ICA)
#
#       WILMORGNAMECODE                CLIENTORG  \
# 0                 ICT  GP Strategies Egypt LLC
# 1                 ICT  GP Strategies Egypt LLC
# 2                 ICA                Tony Ford
# 3                 ICA                Tony Ford
# 4                 ICA         Ann-Marie Patton
# ...               ...                      ...
# 47603             ICA           Liesl Clothier
# 47604             ICA             John Oridupa
# 47605             ICA        Marina Shestakova
# 47606             ICA           Pedro Pinheiro
# 47607             ICA           Richard Evason
#
#                                    OPPORTUNITYNAME   STAGENAME  \
# 0      20180927 IH-HSBC Certificate in FCR - Egypt  Closed Won
# 1      20180927 IH-HSBC Certificate in FCR - Egypt  Closed Won
# 2                      Tony Ford - ICA - 23/3/2019  Closed Won
# 3                      Tony Ford - ICA - 23/3/2019  Closed Won
# 4               Ann-Marie Patton - ICA - 23/3/2019  Closed Won
# ...                                            ...         ...
# 47603      Liesl Clothier - Affiliate - 27/10/2018  Closed Won
# 47604        John Oridupa - Affiliate - 27/10/2018  Closed Won
# 47605    Marina Shestakova - Affiliate - 3/11/2018  Closed Won
# 47606         Associate Pedro Pinheiro - 28/9/2018  Closed Won
# 47607             Richard Evason - ICA - 27/7/2018  Closed Won
#
#                                              PRODUCTNAME FISCALQUARTER  \
# 0      ICA Certificate in Financial Crime Risk - HSBC...        2019 1
# 1      ICA Certificate in Financial Crime Risk - HSBC...        2019 1
# 2                               ICA Associate Membership        2019 3
# 3                               ICA Associate Membership        2019 3
# 4                      ICA (MICA) Membership (12 months)        2019 3
# ...                                                  ...           ...
# 47603               ICA Affiliate Membership (12 months)        2019 2
# 47604               ICA Affiliate Membership (12 months)        2019 2
# 47605               ICA Affiliate Membership (12 months)        2019 2
# 47606                           ICA Associate Membership        2019 1
# 47607                  ICA (MICA) Membership (12 months)        2019 1
#
#                TYPE          CREATEDDATE  ... CREDITNOTETOTALSCALED  \
# 0      New Business  2016-04-21 10:27:11  ...              0.248990
# 1      New Business  2016-04-21 10:27:11  ...              0.248990
# 2      Auto-Renewal  2017-03-23 16:46:51  ...              0.229141
# 3      Auto-Renewal  2017-03-23 16:46:51  ...              0.228567
# 4      Auto-Renewal  2018-03-23 11:54:54  ...              0.229266
# ...             ...                  ...  ...                   ...
# 47603  Auto-Renewal  2016-10-03 12:51:45  ...              0.229104
# 47604  Auto-Renewal  2016-10-27 09:34:20  ...              0.229104
# 47605  Auto-Renewal  2017-12-01 00:04:45  ...              0.229104
# 47606  Auto-Renewal  2016-09-28 10:34:16  ...              0.229141
# 47607  Auto-Renewal  2016-07-27 13:02:28  ...              0.229258
#
#        REVENUESCALED  COSTSCALED  UNITPRICESCALED  PIPETIMEDSCALED  \
# 0           0.470211         0.0         0.068288         0.516640
# 1           0.470211         0.0         0.066516         0.516640
# 2           0.470293         0.0         0.067046         0.471210
# 3           0.470293         0.0         0.067046         0.471210
# 4           0.470328         0.0         0.067277         0.382198
# ...              ...         ...              ...              ...
# 47603       0.470280         0.0         0.066978         0.484945
# 47604       0.470280         0.0         0.066978         0.478605
# 47605       0.470280         0.0         0.066978         0.375066
# 47606       0.470293         0.0         0.067046         0.478870
# 47607       0.470328         0.0         0.067263         0.478605
#
#        TIMEVALSCALED CREDITVALSCALED CNLABEL  CLUSTER  CLUSTERCAT
# 0           0.650453        0.381281   155.0        7           H
# 1           0.650453        0.381281   155.0        7           H
# 2           0.650292        0.381281     8.0        5           F
# 3           0.650292        0.380681     1.0        5           F
# 4           0.650297        0.381281    45.0        2           C
# ...              ...             ...     ...      ...         ...
# 47603       0.650291        0.381281     7.0        4           E
# 47604       0.650291        0.381281     7.0        4           E
# 47605       0.650294        0.381281     7.0        9           K
# 47606       0.650292        0.381281    31.0        3           D
# 47607       0.650293        0.381281    44.0        5           F
#
# [47608 rows x 44 columns]

# %%
ing = bas.select_dtypes('int')
fl = bas.select_dtypes('float')
ob = bas.select_dtypes('object')

# %%
print('Memory usage before data types are changed:')
bas.info(memory_usage = 'deep') 


            

for i in ing.columns:
        if bas[i].astype('int64').any() > 32767:
            bas[i] =  bas[i].astype('int64', errors='raise')
        elif bas[i].astype('int32').between(127, 32767).any():
            bas[i] =  bas[i].astype('int32', errors='raise')
        else:
            bas[i] =  bas[i].astype('int16', errors='raise')

for i in fl.columns:
        if bas[i].astype('float64').max() > 32767:
            bas[i] =  bas[i].astype('float64', errors='raise')
        elif bas[i].astype('float32').between(127, 32767).any():
            bas[i] =  bas[i].astype('float32', errors='raise')
        else:
            bas[i] =  bas[i].astype('float16', errors='raise')    

for i in ob.columns:
        bas[i] = bas[i].astype('category') 

bnn = bas[bas.CNLABEL.notna()].round(0).astype('int64', errors='ignore')
ban = bas[bas.CNLABEL.isna()]
bas = pd.concat([bnn, ban]) 

print('------------------------------------------------------------------------------------------------------------------------------------')
print('Memory usage after data types are changed:')
bas.info(memory_usage='deep')
# Out:
# Memory usage before data types are changed:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47608 entries, 0 to 47607
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   WILMDIVISION           47608 non-null  object
#  1   WILMORGNAME            47608 non-null  object
#  2   WILMORGNAMECODE        47608 non-null  object
#  3   CLIENTORG              47608 non-null  object
#  4   OPPORTUNITYNAME        47608 non-null  object
#  5   STAGENAME              47608 non-null  object
#  6   PRODUCTNAME            47608 non-null  object
#  7   FISCALQUARTER          47608 non-null  object
#  8   TYPE                   47608 non-null  object
#  9   CREATEDDATE            47608 non-null  object
#  10  CLOSEDATE              47608 non-null  object
#  11  AMOUNT                 47608 non-null  float64
#  12  CREDITNOTETOTAL        47608 non-null  float64
#  13  REVENUE                47608 non-null  float64
#  14  COST                   47608 non-null  float64
#  15  UNITPRICE              47608 non-null  float64
#  16  CLOSEDT                47608 non-null  object
#  17  PIPETIME               47608 non-null  object
#  18  PIPETIMED              47608 non-null  int64
#  19  TIMEVAL                47314 non-null  float64
#  20  CREDITVAL              46606 non-null  float64
#  21  WILMORGNAMECODELE      47608 non-null  int64
#  22  CLIENTORGLE            47608 non-null  int64
#  23  OPPORTUNITYNAMELE      47608 non-null  int64
#  24  PRODUCTNAMELE          47608 non-null  int64
#  25  STAGENAMELE            47608 non-null  int64
#  26  FISCALQUARTERLE        47608 non-null  int64
#  27  TYPELE                 47608 non-null  int64
#  28  CREATEDDATELE          47608 non-null  int64
#  29  CLOSEDTLE              47608 non-null  int64
#  30  PIPETIMELE             47608 non-null  int64
#  31  WILMDIVISIONLE         47608 non-null  int64
#  32  WILMORGNAMELE          47608 non-null  int64
#  33  AMOUNTSCALED           47608 non-null  float64
#  34  CREDITNOTETOTALSCALED  47608 non-null  float64
#  35  REVENUESCALED          47608 non-null  float64
#  36  COSTSCALED             47608 non-null  float64
#  37  UNITPRICESCALED        47608 non-null  float64
#  38  PIPETIMEDSCALED        47608 non-null  float64
#  39  TIMEVALSCALED          47608 non-null  float64
#  40  CREDITVALSCALED        47608 non-null  float64
#  41  CNLABEL                47608 non-null  float64
#  42  CLUSTER                47608 non-null  int64
#  43  CLUSTERCAT             47608 non-null  object
# dtypes: float64(16), int64(14), object(14)
# memory usage: 58.7 MB
# ------------------------------------------------------------------------------------------------------------------------------------
# Memory usage after data types are changed:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47608 entries, 0 to 47607
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   WILMDIVISION           47608 non-null  category
#  1   WILMORGNAME            47608 non-null  category
#  2   WILMORGNAMECODE        47608 non-null  category
#  3   CLIENTORG              47608 non-null  category
#  4   OPPORTUNITYNAME        47608 non-null  category
#  5   STAGENAME              47608 non-null  category
#  6   PRODUCTNAME            47608 non-null  category
#  7   FISCALQUARTER          47608 non-null  category
#  8   TYPE                   47608 non-null  category
#  9   CREATEDDATE            47608 non-null  category
#  10  CLOSEDATE              47608 non-null  object
#  11  AMOUNT                 47608 non-null  float64
#  12  CREDITNOTETOTAL        47608 non-null  float64
#  13  REVENUE                47608 non-null  float64
#  14  COST                   47608 non-null  float64
#  15  UNITPRICE              47608 non-null  float64
#  16  CLOSEDT                47608 non-null  category
#  17  PIPETIME               47608 non-null  category
#  18  PIPETIMED              47608 non-null  int64
#  19  TIMEVAL                47314 non-null  float32
#  20  CREDITVAL              46606 non-null  float32
#  21  WILMORGNAMECODELE      47608 non-null  int64
#  22  CLIENTORGLE            47608 non-null  int64
#  23  OPPORTUNITYNAMELE      47608 non-null  int64
#  24  PRODUCTNAMELE          47608 non-null  int64
#  25  STAGENAMELE            47608 non-null  int64
#  26  FISCALQUARTERLE        47608 non-null  int64
#  27  TYPELE                 47608 non-null  int64
#  28  CREATEDDATELE          47608 non-null  int64
#  29  CLOSEDTLE              47608 non-null  int64
#  30  PIPETIMELE             47608 non-null  int64
#  31  WILMDIVISIONLE         47608 non-null  int64
#  32  WILMORGNAMELE          47608 non-null  int64
#  33  AMOUNTSCALED           47608 non-null  float64
#  34  CREDITNOTETOTALSCALED  47608 non-null  float64
#  35  REVENUESCALED          47608 non-null  float64
#  36  COSTSCALED             47608 non-null  float64
#  37  UNITPRICESCALED        47608 non-null  float64
#  38  PIPETIMEDSCALED        47608 non-null  float64
#  39  TIMEVALSCALED          47608 non-null  float64
#  40  CREDITVALSCALED        47608 non-null  float64
#  41  CNLABEL                47608 non-null  float32
#  42  CLUSTER                47608 non-null  int64
#  43  CLUSTERCAT             47608 non-null  category
# dtypes: category(13), float32(3), float64(13), int64(14), object(1)
# memory usage: 22.5 MB

# %%
allClients = (bas.CLIENTORG.unique()) 

allWilm = (bas.WILMORGNAME.unique()) 


allType = (bas.TYPE.unique()) 

allWEEKs = 0

defaultTargetProf =  1265.88

defaultTargetPecent=  120

allOpps = bas.OPPORTUNITYNAME.unique()

# %%
bas['WEEK'] = bas.PIPETIMED/7

# %%
bt = bas[['WILMORGNAMELE', 'STAGENAMELE',
       'TYPELE', 'AMOUNT', 'PIPETIMED', 'REVENUE', 'CREDITNOTETOTAL']]

corr = bt.corr(method ='kendall')

sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %%
cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

toCorr = bas[['WILMORGNAMELE', 'STAGENAMELE','TYPELE', 'AMOUNT', 'PIPETIMED', 'REVENUE', 'CREDITNOTETOTAL']]
corr = toCorr.corr(method ='kendall')

corr.style.background_gradient(cmap, axis=1)\
.set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
.set_caption("Hover to magify")\
.set_precision(2)\
.set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_141e5_ th {
#           font-size: 7pt;
#     }    #T_141e5_ td {
#           padding: 0em 0em;
#     }    #T_141e5_ th:hover {
#           font-size: 12pt;
#     }    #T_141e5_ tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }#T_141e5_row0_col0,#T_141e5_row1_col1,#T_141e5_row2_col2,#T_141e5_row3_col3,#T_141e5_row4_col4,#T_141e5_row5_col5,#T_141e5_row6_col6{
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row0_col1,#T_141e5_row1_col3,#T_141e5_row1_col5,#T_141e5_row2_col1,#T_141e5_row3_col1,#T_141e5_row4_col2,#T_141e5_row4_col5,#T_141e5_row5_col1,#T_141e5_row6_col0{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row0_col2{
#             background-color:  #df7086;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row0_col3,#T_141e5_row0_col5{
#             background-color:  #e59aa9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row0_col4{
#             background-color:  #df7288;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row0_col6{
#             background-color:  #dc5b75;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row1_col0{
#             background-color:  #e7a3b0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row1_col2{
#             background-color:  #e17a8f;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row1_col4{
#             background-color:  #f0e0e3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row1_col6{
#             background-color:  #eed2d7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row2_col0{
#             background-color:  #e599a8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row2_col3{
#             background-color:  #d1dbe8;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row2_col4{
#             background-color:  #e494a4;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row2_col5{
#             background-color:  #d3dce9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row2_col6{
#             background-color:  #dee4ec;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row3_col0,#T_141e5_row5_col0{
#             background-color:  #f1e5e7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row3_col2{
#             background-color:  #b9cae0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row3_col4{
#             background-color:  #ecc5cc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row3_col5,#T_141e5_row5_col3{
#             background-color:  #497dbc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row3_col6{
#             background-color:  #f2ebec;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row4_col0{
#             background-color:  #d84462;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row4_col1{
#             background-color:  #de6980;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row4_col3{
#             background-color:  #d73d5c;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row4_col6{
#             background-color:  #db5872;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row5_col2{
#             background-color:  #bacbe1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row5_col4{
#             background-color:  #ecc3cb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row5_col6{
#             background-color:  #f1e8ea;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row6_col1{
#             background-color:  #dd6179;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row6_col2{
#             background-color:  #efdcdf;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row6_col3{
#             background-color:  #e28799;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row6_col4{
#             background-color:  #de667e;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_141e5_row6_col5{
#             background-color:  #e28497;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }</style><table id="T_141e5_" ><caption>Hover to magify</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >WILMORGNAMELE</th>        <th class="col_heading level0 col1" >STAGENAMELE</th>        <th class="col_heading level0 col2" >TYPELE</th>        <th class="col_heading level0 col3" >AMOUNT</th>        <th class="col_heading level0 col4" >PIPETIMED</th>        <th class="col_heading level0 col5" >REVENUE</th>        <th class="col_heading level0 col6" >CREDITNOTETOTAL</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_141e5_level0_row0" class="row_heading level0 row0" >WILMORGNAMELE</th>
#                         <td id="T_141e5_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_141e5_row0_col1" class="data row0 col1" >-0.21</td>
#                         <td id="T_141e5_row0_col2" class="data row0 col2" >-0.03</td>
#                         <td id="T_141e5_row0_col3" class="data row0 col3" >0.11</td>
#                         <td id="T_141e5_row0_col4" class="data row0 col4" >-0.03</td>
#                         <td id="T_141e5_row0_col5" class="data row0 col5" >0.10</td>
#                         <td id="T_141e5_row0_col6" class="data row0 col6" >-0.10</td>
#             </tr>
#             <tr>
#                         <th id="T_141e5_level0_row1" class="row_heading level0 row1" >STAGENAMELE</th>
#                         <td id="T_141e5_row1_col0" class="data row1 col0" >-0.21</td>
#                         <td id="T_141e5_row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_141e5_row1_col2" class="data row1 col2" >-0.39</td>
#                         <td id="T_141e5_row1_col3" class="data row1 col3" >-0.68</td>
#                         <td id="T_141e5_row1_col4" class="data row1 col4" >0.08</td>
#                         <td id="T_141e5_row1_col5" class="data row1 col5" >-0.68</td>
#                         <td id="T_141e5_row1_col6" class="data row1 col6" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_141e5_level0_row2" class="row_heading level0 row2" >TYPELE</th>
#                         <td id="T_141e5_row2_col0" class="data row2 col0" >-0.03</td>
#                         <td id="T_141e5_row2_col1" class="data row2 col1" >-0.39</td>

# %%
bas.select_dtypes(np.number).columns   
basNum = ['AMOUNT', 'CREDITNOTETOTAL', 'REVENUE', 'COST', 'UNITPRICE',
       'PIPETIMED', 'TIMEVAL', 'CREDITVAL', 'WILMORGNAMECODELE', 'CLIENTORGLE',
       'OPPORTUNITYNAMELE', 'PRODUCTNAMELE', 'STAGENAMELE', 'FISCALQUARTERLE',
       'TYPELE', 'CREATEDDATELE', 'CLOSEDTLE', 'PIPETIMELE', 'WILMDIVISIONLE',
       'WILMORGNAMELE']

# %%
bas = bas.sample(frac = 0.05)

# %%
def CorMap(FeaturesToCorrelate = bas.select_dtypes(np.number).columns):

    cmap=sns.diverging_palette(5, 250, as_cmap=True)

    toCorr = bas[FeaturesToCorrelate]
    corr = toCorr.corr(method ='kendall')

    TableStyles = [dict(selector="th",
                     props=[("font-size", "7pt")]),
                dict(selector="td",
                     props=[('padding', "0em 0em")]),
                dict(selector="th:hover",
                     props=[("font-size", "12pt")]),
                dict(selector="tr:hover td:hover",
                     props=[('max-width', '200px'),
                            ('font-size', '12pt')])
    ]

   
    return corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(TableStyles)
    
CorMap(['AMOUNT', 'CREDITNOTETOTAL', 'REVENUE', 'COST', 'UNITPRICE',
       'PIPETIMED', 'TIMEVAL', 'CREDITVAL', 'WILMORGNAMECODELE', 'CLIENTORGLE',
       'OPPORTUNITYNAMELE', 'PRODUCTNAMELE', 'STAGENAMELE', 'FISCALQUARTERLE',
       'TYPELE', 'CREATEDDATELE', 'CLOSEDTLE', 'PIPETIMELE', 'WILMDIVISIONLE',
       'WILMORGNAMELE', 'AMOUNTSCALED'])    
    
 
# CorMap(['WILMDIVISIONLE', 'WILMORGNAMELE', 'CLIENTORGLE',
#        'OPPORTUNITYNAMELE', 'STAGENAMELE', 'TYPELE', 'AMOUNT', 'REVENUE',
#        'UNITPRICE', 'CREDITNOTETOTAL', 'FISCALQUARTER', 'CREATEDATE',
#        'CLOSEDATE', 'PIPETIME', 'PIPETIMED', 'TIMEVAL', 'CREDITVAL',
#        'TIMEVALSCALED', 'PIPETIMEDSCALED', 'CREDITNOTESCALED', 'AMOUNTSCALED',
#        'CREDITVALSCALED', 'CNLABEL', 'CLUSTER', 'CLUSTERCAT', 'WEEK'])

CorMap(['AMOUNT', 'CREDITNOTETOTAL', 'REVENUE', 'COST', 'UNITPRICE',
       'PIPETIMED', 'TIMEVAL', 'CREDITVAL', 'WILMORGNAMECODELE', 'CLIENTORGLE',
       'OPPORTUNITYNAMELE', 'PRODUCTNAMELE', 'STAGENAMELE', 'FISCALQUARTERLE',
       'TYPELE', 'CREATEDDATELE', 'CLOSEDTLE', 'PIPETIMELE', 'WILMDIVISIONLE',
       'WILMORGNAMELE', 'AMOUNTSCALED'])
# Out:
# <style  type="text/css" >
#     #T_2ce14_ th {
#           font-size: 7pt;
#     }    #T_2ce14_ td {
#           padding: 0em 0em;
#     }    #T_2ce14_ th:hover {
#           font-size: 12pt;
#     }    #T_2ce14_ tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }#T_2ce14_row0_col0,#T_2ce14_row0_col20,#T_2ce14_row1_col1,#T_2ce14_row2_col2,#T_2ce14_row4_col4,#T_2ce14_row5_col5,#T_2ce14_row6_col6,#T_2ce14_row7_col7,#T_2ce14_row8_col8,#T_2ce14_row9_col9,#T_2ce14_row10_col10,#T_2ce14_row11_col11,#T_2ce14_row12_col12,#T_2ce14_row13_col13,#T_2ce14_row14_col14,#T_2ce14_row15_col15,#T_2ce14_row16_col16,#T_2ce14_row17_col17,#T_2ce14_row18_col18,#T_2ce14_row19_col19,#T_2ce14_row20_col0,#T_2ce14_row20_col20{
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col1,#T_2ce14_row12_col17,#T_2ce14_row20_col1{
#             background-color:  #f2ebec;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col2,#T_2ce14_row2_col0,#T_2ce14_row2_col20,#T_2ce14_row20_col2{
#             background-color:  #497dbc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col3,#T_2ce14_row1_col3,#T_2ce14_row2_col3,#T_2ce14_row4_col3,#T_2ce14_row5_col3,#T_2ce14_row6_col3,#T_2ce14_row7_col3,#T_2ce14_row8_col3,#T_2ce14_row9_col3,#T_2ce14_row10_col3,#T_2ce14_row11_col3,#T_2ce14_row12_col3,#T_2ce14_row13_col3,#T_2ce14_row14_col3,#T_2ce14_row15_col3,#T_2ce14_row16_col3,#T_2ce14_row17_col3,#T_2ce14_row18_col3,#T_2ce14_row19_col3,#T_2ce14_row20_col3{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col4,#T_2ce14_row10_col17,#T_2ce14_row20_col4{
#             background-color:  #e491a1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col5,#T_2ce14_row5_col2,#T_2ce14_row5_col7,#T_2ce14_row7_col17,#T_2ce14_row10_col19,#T_2ce14_row20_col5{
#             background-color:  #ecc5cc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col6,#T_2ce14_row20_col6{
#             background-color:  #a3bbd9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col7,#T_2ce14_row20_col7{
#             background-color:  #a9bfdb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col8,#T_2ce14_row0_col10,#T_2ce14_row2_col10,#T_2ce14_row6_col7,#T_2ce14_row14_col1,#T_2ce14_row20_col8,#T_2ce14_row20_col10{
#             background-color:  #dee4ec;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col9,#T_2ce14_row2_col9,#T_2ce14_row14_col18,#T_2ce14_row15_col7,#T_2ce14_row15_col11,#T_2ce14_row20_col9{
#             background-color:  #edcdd3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col11,#T_2ce14_row2_col1,#T_2ce14_row20_col11{
#             background-color:  #f1e8ea;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col12,#T_2ce14_row1_col19,#T_2ce14_row2_col12,#T_2ce14_row3_col0,#T_2ce14_row3_col1,#T_2ce14_row3_col2,#T_2ce14_row3_col3,#T_2ce14_row3_col4,#T_2ce14_row3_col5,#T_2ce14_row3_col6,#T_2ce14_row3_col7,#T_2ce14_row3_col8,#T_2ce14_row3_col9,#T_2ce14_row3_col10,#T_2ce14_row3_col11,#T_2ce14_row3_col12,#T_2ce14_row3_col13,#T_2ce14_row3_col14,#T_2ce14_row3_col15,#T_2ce14_row3_col16,#T_2ce14_row3_col17,#T_2ce14_row3_col18,#T_2ce14_row3_col19,#T_2ce14_row3_col20,#T_2ce14_row4_col18,#T_2ce14_row5_col15,#T_2ce14_row6_col12,#T_2ce14_row7_col12,#T_2ce14_row8_col12,#T_2ce14_row9_col5,#T_2ce14_row10_col12,#T_2ce14_row11_col19,#T_2ce14_row12_col7,#T_2ce14_row13_col7,#T_2ce14_row14_col12,#T_2ce14_row15_col5,#T_2ce14_row16_col7,#T_2ce14_row17_col14,#T_2ce14_row18_col12,#T_2ce14_row19_col12,#T_2ce14_row20_col12{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col13,#T_2ce14_row2_col13,#T_2ce14_row5_col10,#T_2ce14_row18_col9,#T_2ce14_row18_col15,#T_2ce14_row20_col13{
#             background-color:  #ebc2ca;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col14,#T_2ce14_row2_col18,#T_2ce14_row20_col14{
#             background-color:  #b9cae0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col15,#T_2ce14_row5_col11,#T_2ce14_row7_col15,#T_2ce14_row15_col8,#T_2ce14_row20_col15{
#             background-color:  #edd0d6;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col16,#T_2ce14_row2_col5,#T_2ce14_row2_col16,#T_2ce14_row6_col19,#T_2ce14_row20_col16{
#             background-color:  #ecc3cb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col17,#T_2ce14_row20_col17{
#             background-color:  #eab7c1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col18,#T_2ce14_row2_col14,#T_2ce14_row20_col18{
#             background-color:  #bacbe1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row0_col19,#T_2ce14_row2_col19,#T_2ce14_row5_col13,#T_2ce14_row5_col16,#T_2ce14_row20_col19{
#             background-color:  #f1e5e7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row1_col0,#T_2ce14_row1_col20,#T_2ce14_row16_col5{
#             background-color:  #e28799;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row1_col2{
#             background-color:  #e28497;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row1_col4,#T_2ce14_row11_col10,#T_2ce14_row16_col4,#T_2ce14_row19_col18{
#             background-color:  #de687f;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row1_col5,#T_2ce14_row4_col7,#T_2ce14_row13_col11,#T_2ce14_row14_col17{
#             background-color:  #de667e;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row1_col6{
#             background-color:  #db526e;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row1_col7{
#             background-color:  #d83e5d;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row1_col8,#T_2ce14_row11_col6,#T_2ce14_row17_col10{
#             background-color:  #e0768b;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row1_col9,#T_2ce14_row1_col15,#T_2ce14_row13_col0,#T_2ce14_row13_col2,#T_2ce14_row13_col20,#T_2ce14_row16_col2{
#             background-color:  #db5872;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row1_col10,#T_2ce14_row8_col18,#T_2ce14_row9_col15,#T_2ce14_row17_col0,#T_2ce14_row17_col2,#T_2ce14_row17_col20,#T_2ce14_row19_col11{
#             background-color:  #dc5c76;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row1_col11,#T_2ce14_row8_col11,#T_2ce14_row11_col14,#T_2ce14_row13_col1{
#             background-color:  #e38d9e;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2ce14_row1_col12{
#             background-color:  #dd6179;

# %%
pd.set_option('display.max_rows',100)
#Cell > All Outputs > Toggle Scrolling (On the Menu Bar) to show entire output of function

def Above20orXIncrease(ClientOrg = allClients, Type = allType, MinWeeksToComplete = 0,  WILMORGNAME = allWilm, Opportunities = allOpps, TargetMinRevenue = -99999999, TargetMinPercentRevenue = -9999999, forCorr = basNum):
    
    OrgMask = bas.CLIENTORG.isin(ClientOrg)
    TypeMask = bas.TYPE.isin(Type)
    PipeMask = bas.WEEK > MinWeeksToComplete
    WILMORGNAMEMask = bas.WILMORGNAME.isin(WILMORGNAME)
    RevenueMask =  bas.REVENUE > TargetMinRevenue 
    PercentMask =  bas.REVENUE > (1054.9 * (TargetMinPercentRevenue/100)) 
    OppMask =  bas.OPPORTUNITYNAME.isin(Opportunities)

    
    bashighProf = bas[(OrgMask) & (TypeMask) & (PipeMask)  & (WILMORGNAMEMask) & (RevenueMask) & (PercentMask) & (OppMask)] 

    y = bas[(OrgMask) & (TypeMask) & (PipeMask)  & (WILMORGNAMEMask)].REVENUE.mean()
    yi = bas.REVENUE.mean() 
    
    Percentagediff = ((y-yi) / yi * 100) 
    print('Likely Revenue Given Input:', round(y,2), '    Average Opportunity Revenue:', round(yi,2), 
          '    Average vs Likely (% Difference):', round(Percentagediff, 2), )
    
  
    PossibleWILMORGNAMEs = bashighProf.groupby(['WILMORGNAME']).agg({'REVENUE': ['mean']}).reset_index()
    PossibleWILMORGNAMEs = pd.DataFrame(PossibleWILMORGNAMEs)
    PossibleWILMORGNAMEs.columns = ['Wilm Orgs Meeting Targets, ranked by revenue', 'Average Revenue']
    PossibleWILMORGNAMEs =  PossibleWILMORGNAMEs.sort_values(by = 'Average Revenue',ascending=False).dropna(axis=0, how='any')
    
    PossibleClientOrgs = bashighProf.groupby(['CLIENTORG']).agg({'REVENUE': ['mean']}).reset_index()
    PossibleClientOrgs = pd.DataFrame(PossibleClientOrgs)
    PossibleClientOrgs.columns = ['Clients Meeting Targets, ranked', 'Average Revenue']
    PossibleClientOrgs =  PossibleClientOrgs.sort_values(by = 'Average Revenue',ascending=False).dropna(axis=0, how='any')
    
    PossibleTypes = bashighProf.groupby(['TYPE']).agg({'REVENUE': ['mean']}).reset_index()
    PossibleTypes = pd.DataFrame(PossibleTypes)
    PossibleTypes.columns = ['Opportunity types meeting Targets, ranked', 'Average Revenue']
    PossibleTypes =  PossibleTypes.sort_values(by = 'Average Revenue',ascending=False).dropna(axis=0, how='any')
    
    PossibleDivisions = bashighProf.groupby(['WILMDIVISION']).agg({'REVENUE': ['mean']}).reset_index()
    PossibleDivisions = pd.DataFrame(PossibleDivisions)
    PossibleDivisions.columns = ['Divisions Meeting Targets, ranked', 'Average Revenue']
    PossibleDivisions =  PossibleDivisions.sort_values(by = 'Average Revenue',ascending=False).dropna(axis=0, how='any')
    
    

    
      
    print("--------------------------------------------------------------------------------------------------------- ")
    print('Features that have given a Revenue above target absolute and percentage revenue with selected dimensions:'),
    display(PossibleWILMORGNAMEs), display(PossibleTypes), display(PossibleDivisions), display(PossibleClientOrgs)

    print("--------------------------------------------------------------------------------------------------------- ")
    print('Unique combinations of features with a Revenue above set revenue targets and within combinations:'),
       
    
  #  AllCombinations = bas.sample(frac=.3).groupby(['WILMDIVISION','WILMORGNAME', 'CLIENTORG', 'TYPE']).agg({'REVENUE': ['mean', 'std'], 'PIPETIMED': 'mean'}).reset_index()#, 'PIPETIMED': ['mean']})
  #  AllCombinations = pd.DataFrame(AllCombinations)

   # AllCombinations.columns = ['WILMDIVISION','WILMORGNAME', 'CLIENTORG', 'TYPE', 'Average Revenue', 'Avg Revenue Standard Deviation', 'Average Open To Close Days']#, 'Avg Revenue Max']
   # display(AllCombinations.sort_values(by = 'Average Revenue',ascending=False))
    
    print("--------------------------------------------------------------------------------------------------------- ")
    print('Correlaton between selected dimensions converted to numeric format, and measures, with selected dimensions:'),
    
#     toCorr = bashighProf[forCorr]
#     corr = toCorr.corr(method ='kendall')
#     display(corr)
    
    display(CorMap(FeaturesToCorrelate = forCorr))


    
#     cmap=sns.diverging_palette(5, 250, as_cmap=True)


#     TableStyles = [dict(selector="th",
#                      props=[("font-size", "7pt")]),
#                 dict(selector="td",
#                      props=[('padding', "0em 0em")]),
#                 dict(selector="th:hover",
#                      props=[("font-size", "12pt")]),
#                 dict(selector="tr:hover td:hover",
#                      props=[('max-width', '200px'),
#                             ('font-size', '12pt')])
#     ]

   
#     display (corr.style.background_gradient(cmap, axis=1)\
#     .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
#     .set_caption("Hover to magify")\
#     .set_precision(2)\
#     .set_table_styles(TableStyles)) 
     


    
    
    
Above20orXIncrease(TargetMinPercentRevenue = 130, MinWeeksToComplete = 40)#, WILMORGNAME = ['ICA']) #Opportunities=['Credit Of W-1113094 Various HMRC remaining licenses'], , TargetMinRevenue = 1265.88,  TargetMinPercentRevenue = 120)
# Out:
# Likely Revenue Given Input: 4681.51     Average Opportunity Revenue: 3845.99     Average vs Likely (% Difference): 21.72
# ---------------------------------------------------------------------------------------------------------
# Features that have given a Revenue above target absolute and percentage revenue with selected dimensions:
#          Wilm Orgs Meeting Targets, ranked by revenue  Average Revenue
# 17                          Wilmington Healthcare Ltd    157749.011605
# 8                                       ICTA Malaysia    134163.381295
# 15                                      Smee and Ford     71212.692308
# 6                                   ICA Audit Limited     67973.733333
# 1           Adkins Matchett & Toy (Hong Kong) Limited     25079.673077
# 12  International Compliance Training Academy Pte Ltd     21288.601566
# 11         International Compliance Training (ME) Ltd     19193.016796
# 7                         ICA Commercial Services Ltd     19003.656845
# 10         International Compliance Association (ICA)     12278.431515
# 14                                   Mercia Group Ltd      9191.818182
# 16                                     Wilmington FRA      8333.333333
# 18            Wilmington Publishing & Information Ltd      8213.581515
# 2                                          Bond Solon      4943.264000
# 0                                 ARK Conferences Ltd      3860.526316
# 3                               CLT International Ltd      3462.984085
# 13                             La Touche Training Ltd      3139.147917
# 9                            Interactive Medica Spain      2238.872174
# 4                                Central Law Training      1800.000000
# 5                 Central Law Training (Scotland) Ltd      1603.801653
#   Opportunity types meeting Targets, ranked  Average Revenue
# 3          New Business - Existing Customer     31197.550000
# 4                                   Renewal     28408.934775
# 2                              New Business     21171.387172
# 5                           Repeat Business     20830.856471
# 6                          Transfer/Reissue     11609.680556
# 0                              Auto-Renewal      8760.930000
# 1                                    Credit      8372.222222
#   Divisions Meeting Targets, ranked  Average Revenue
# 0                        Healthcare     75910.187196
# 2                 Risk & Compliance     20555.158730
# 1                      Professional      2915.261329
#           Clients Meeting Targets, ranked  Average Revenue
# 458       Prudential Distribution Limited    750000.000000
# 401          Napp Pharmaceuticals Limited    416172.820000
# 41   Asian Institute of Chartered Bankers    147487.554404
# 611              United Overseas Bank Ltd    146363.684211
# 49                B Braun Medical Limited     96446.140000
# ..                                    ...              ...
# 318   Kingstons Will & Trust Planning Ltd      1395.000000
# 632     Willoughby Corporate Services Ltd      1395.000000
# 14                                Accuity      1390.000000
# 503                      Samantha Worrell      1390.000000
# 441                             PT Djarum      1390.000000
#
# [652 rows x 2 columns]
# ---------------------------------------------------------------------------------------------------------
# Unique combinations of features with a Revenue above set revenue targets and within combinations:
# ---------------------------------------------------------------------------------------------------------
# Correlaton between selected dimensions converted to numeric format, and measures, with selected dimensions:
#                      AMOUNT  CREDITNOTETOTAL   REVENUE  COST  UNITPRICE  \
# AMOUNT             1.000000         0.339547  0.934799   NaN   0.010347
# CREDITNOTETOTAL    0.339547         1.000000  0.335466   NaN   0.027300
# REVENUE            0.934799         0.335466  1.000000   NaN  -0.001728
# COST                    NaN              NaN       NaN   1.0        NaN
# UNITPRICE          0.010347         0.027300 -0.001728   NaN   1.000000
# PIPETIMED          0.127726         0.077700  0.134806   NaN   0.010867
# TIMEVAL            0.731258         0.206157  0.701168   NaN   0.006641
# CREDITVAL          0.301962        -0.201835  0.290194   NaN   0.009474
# WILMORGNAMECODELE  0.111960         0.026977  0.108256   NaN  -0.051319
# CLIENTORGLE       -0.148313        -0.055465 -0.151328   NaN  -0.007663
# OPPORTUNITYNAMELE  0.008967         0.051174  0.010432   NaN  -0.022135
# PRODUCTNAMELE      0.005342         0.066410  0.001104   NaN   0.037757
# STAGENAMELE       -0.107227        -0.007316 -0.119417   NaN  -0.022448
# FISCALQUARTERLE    0.156593         0.072173  0.159315   NaN  -0.062398
# TYPELE             0.066607        -0.030042  0.036622   NaN   0.068027
# CREATEDDATELE     -0.058398        -0.032973 -0.064597   NaN  -0.047068
# CLOSEDTLE          0.149397         0.071989  0.152237   NaN  -0.056955
# PIPETIMELE         0.012549        -0.069395  0.009645   NaN  -0.022765
# WILMDIVISIONLE     0.076369         0.065739  0.100484   NaN  -0.151912
# WILMORGNAMELE      0.069711         0.043565  0.059573   NaN   0.069977
#
#                    PIPETIMED   TIMEVAL  CREDITVAL  WILMORGNAMECODELE  \
# AMOUNT              0.127726  0.731258   0.301962           0.111960
# CREDITNOTETOTAL     0.077700  0.206157  -0.201835           0.026977
# REVENUE             0.134806  0.701168   0.290194           0.108256
# COST                     NaN       NaN        NaN                NaN
# UNITPRICE           0.010867  0.006641   0.009474          -0.051319
# PIPETIMED           1.000000 -0.145431   0.010710           0.132360
# TIMEVAL            -0.145431  1.000000   0.320245           0.031885
# CREDITVAL           0.010710  0.320245   1.000000          -0.039363
# WILMORGNAMECODELE   0.132360  0.031885  -0.039363           1.000000
# CLIENTORGLE        -0.143787 -0.108079  -0.060109           0.024561
# OPPORTUNITYNAMELE  -0.118773  0.025135  -0.025638           0.021966
# PRODUCTNAMELE      -0.017389 -0.027941  -0.059118           0.068818
# STAGENAMELE        -0.172436 -0.081063   0.010555          -0.115086
# FISCALQUARTERLE     0.234180  0.083333   0.086541           0.084066
# TYPELE              0.002780  0.067373   0.055801          -0.089557
# CREATEDDATELE      -0.619796  0.158032   0.031372          -0.131037
# CLOSEDTLE           0.232061  0.078681   0.078547           0.079344
# PIPETIMELE          0.064028  0.125798   0.003403          -0.001713
# WILMDIVISIONLE     -0.014854  0.074797   0.012000          -0.177565
# WILMORGNAMELE      -0.066470  0.100250   0.036112          -0.106308
#
#                    CLIENTORGLE  OPPORTUNITYNAMELE  PRODUCTNAMELE  STAGENAMELE  \
# AMOUNT               -0.148313           0.008967       0.005342    -0.107227
# CREDITNOTETOTAL      -0.055465           0.051174       0.066410    -0.007316
# REVENUE              -0.151328           0.010432       0.001104    -0.119417
# COST                       NaN                NaN            NaN          NaN
# UNITPRICE            -0.007663          -0.022135       0.037757    -0.022448
# PIPETIMED            -0.143787          -0.118773      -0.017389    -0.172436
# TIMEVAL              -0.108079           0.025135      -0.027941    -0.081063
# CREDITVAL            -0.060109          -0.025638      -0.059118     0.010555
# WILMORGNAMECODELE     0.024561           0.021966       0.068818    -0.115086
# CLIENTORGLE           1.000000           0.270555       0.073015     0.142027
# OPPORTUNITYNAMELE     0.270555           1.000000       0.170785     0.164323
# PRODUCTNAMELE         0.073015           0.170785       1.000000     0.020986
# STAGENAMELE           0.142027           0.164323       0.020986     1.000000
# FISCALQUARTERLE       0.007226           0.010204      -0.047748    -0.087021
# TYPELE                0.014050           0.016985      -0.030809    -0.015379
# CREATEDDATELE         0.157803           0.136576      -0.012785     0.175437
# CLOSEDTLE             0.006732           0.003621      -0.045122    -0.090833
# PIPETIMELE            0.039708          -0.003163       0.005341    -0.035607
# WILMDIVISIONLE       -0.040086          -0.018233      -0.136593     0.039787
# WILMORGNAMELE        -0.022914          -0.061408      -0.260763     0.013779
#
#                    FISCALQUARTERLE    TYPELE  CREATEDDATELE  CLOSEDTLE  \
# AMOUNT                    0.156593  0.066607      -0.058398   0.149397
# CREDITNOTETOTAL           0.072173 -0.030042      -0.032973   0.071989
# REVENUE                   0.159315  0.036622      -0.064597   0.152237
# COST                           NaN       NaN            NaN        NaN
# UNITPRICE                -0.062398  0.068027      -0.047068  -0.056955
# PIPETIMED                 0.234180  0.002780      -0.619796   0.232061
# TIMEVAL                   0.083333  0.067373       0.158032   0.078681
# CREDITVAL                 0.086541  0.055801       0.031372   0.078547
# WILMORGNAMECODELE         0.084066 -0.089557      -0.131037   0.079344
# CLIENTORGLE               0.007226  0.014050       0.157803   0.006732
# OPPORTUNITYNAMELE         0.010204  0.016985       0.136576   0.003621
# PRODUCTNAMELE            -0.047748 -0.030809      -0.012785  -0.045122
# STAGENAMELE              -0.087021 -0.015379       0.175437  -0.090833
# FISCALQUARTERLE           1.000000  0.032272       0.158504   0.958031
# TYPELE                    0.032272  1.000000       0.016077   0.031293
# CREATEDDATELE             0.158504  0.016077       1.000000   0.151552
# CLOSEDTLE                 0.958031  0.031293       0.151552   1.000000
# PIPETIMELE                0.080256 -0.002294       0.218159   0.084628
# WILMDIVISIONLE            0.079711  0.025359       0.058220   0.077276
# WILMORGNAMELE             0.002968  0.046174       0.100365   0.001727
#
#                    PIPETIMELE  WILMDIVISIONLE  WILMORGNAMELE
# AMOUNT               0.012549        0.076369       0.069711
# CREDITNOTETOTAL     -0.069395        0.065739       0.043565
# REVENUE              0.009645        0.100484       0.059573
# COST                      NaN             NaN            NaN
# UNITPRICE           -0.022765       -0.151912       0.069977
# PIPETIMED            0.064028       -0.014854      -0.066470
# TIMEVAL              0.125798        0.074797       0.100250
# CREDITVAL            0.003403        0.012000       0.036112
# WILMORGNAMECODELE   -0.001713       -0.177565      -0.106308
# CLIENTORGLE          0.039708       -0.040086      -0.022914
# OPPORTUNITYNAMELE   -0.003163       -0.018233      -0.061408
# PRODUCTNAMELE        0.005341       -0.136593      -0.260763
# STAGENAMELE         -0.035607        0.039787       0.013779
# FISCALQUARTERLE      0.080256        0.079711       0.002968
# TYPELE              -0.002294        0.025359       0.046174
# CREATEDDATELE        0.218159        0.058220       0.100365
# CLOSEDTLE            0.084628        0.077276       0.001727
# PIPETIMELE           1.000000       -0.016555       0.033747
# WILMDIVISIONLE      -0.016555        1.000000      -0.179398
# WILMORGNAMELE        0.033747       -0.179398       1.000000
# <style  type="text/css" >
#     #T_2a19e_ th {
#           font-size: 7pt;
#     }    #T_2a19e_ td {
#           padding: 0em 0em;
#     }    #T_2a19e_ th:hover {
#           font-size: 12pt;
#     }    #T_2a19e_ tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }#T_2a19e_row0_col0,#T_2a19e_row1_col1,#T_2a19e_row2_col2,#T_2a19e_row4_col4,#T_2a19e_row5_col5,#T_2a19e_row6_col6,#T_2a19e_row7_col7,#T_2a19e_row8_col8,#T_2a19e_row9_col9,#T_2a19e_row10_col10,#T_2a19e_row11_col11,#T_2a19e_row12_col12,#T_2a19e_row13_col13,#T_2a19e_row14_col14,#T_2a19e_row15_col15,#T_2a19e_row16_col16,#T_2a19e_row17_col17,#T_2a19e_row18_col18,#T_2a19e_row19_col19{
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col1,#T_2a19e_row12_col17{
#             background-color:  #f2ebec;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col2,#T_2a19e_row2_col0{
#             background-color:  #497dbc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col3,#T_2a19e_row1_col3,#T_2a19e_row2_col3,#T_2a19e_row4_col3,#T_2a19e_row5_col3,#T_2a19e_row6_col3,#T_2a19e_row7_col3,#T_2a19e_row8_col3,#T_2a19e_row9_col3,#T_2a19e_row10_col3,#T_2a19e_row11_col3,#T_2a19e_row12_col3,#T_2a19e_row13_col3,#T_2a19e_row14_col3,#T_2a19e_row15_col3,#T_2a19e_row16_col3,#T_2a19e_row17_col3,#T_2a19e_row18_col3,#T_2a19e_row19_col3{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col4,#T_2a19e_row10_col17{
#             background-color:  #e491a1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col5,#T_2a19e_row5_col2,#T_2a19e_row5_col7,#T_2a19e_row7_col17,#T_2a19e_row10_col19{
#             background-color:  #ecc5cc;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col6{
#             background-color:  #a3bbd9;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col7{
#             background-color:  #a9bfdb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col8,#T_2a19e_row0_col10,#T_2a19e_row2_col10,#T_2a19e_row6_col7,#T_2a19e_row14_col1{
#             background-color:  #dee4ec;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col9,#T_2a19e_row2_col9,#T_2a19e_row14_col18,#T_2a19e_row15_col7,#T_2a19e_row15_col11{
#             background-color:  #edcdd3;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col11,#T_2a19e_row2_col1{
#             background-color:  #f1e8ea;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col12,#T_2a19e_row1_col19,#T_2a19e_row2_col12,#T_2a19e_row3_col0,#T_2a19e_row3_col1,#T_2a19e_row3_col2,#T_2a19e_row3_col3,#T_2a19e_row3_col4,#T_2a19e_row3_col5,#T_2a19e_row3_col6,#T_2a19e_row3_col7,#T_2a19e_row3_col8,#T_2a19e_row3_col9,#T_2a19e_row3_col10,#T_2a19e_row3_col11,#T_2a19e_row3_col12,#T_2a19e_row3_col13,#T_2a19e_row3_col14,#T_2a19e_row3_col15,#T_2a19e_row3_col16,#T_2a19e_row3_col17,#T_2a19e_row3_col18,#T_2a19e_row3_col19,#T_2a19e_row4_col18,#T_2a19e_row5_col15,#T_2a19e_row6_col12,#T_2a19e_row7_col12,#T_2a19e_row8_col12,#T_2a19e_row9_col5,#T_2a19e_row10_col12,#T_2a19e_row11_col19,#T_2a19e_row12_col7,#T_2a19e_row13_col7,#T_2a19e_row14_col12,#T_2a19e_row15_col5,#T_2a19e_row16_col7,#T_2a19e_row17_col14,#T_2a19e_row18_col12,#T_2a19e_row19_col12{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col13,#T_2a19e_row2_col13,#T_2a19e_row5_col10,#T_2a19e_row18_col9,#T_2a19e_row18_col15{
#             background-color:  #ebc2ca;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col14,#T_2a19e_row2_col18{
#             background-color:  #b9cae0;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col15,#T_2a19e_row5_col11,#T_2a19e_row7_col15,#T_2a19e_row15_col8{
#             background-color:  #edd0d6;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col16,#T_2a19e_row2_col5,#T_2a19e_row2_col16,#T_2a19e_row6_col19{
#             background-color:  #ecc3cb;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col17{
#             background-color:  #eab7c1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col18,#T_2a19e_row2_col14{
#             background-color:  #bacbe1;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row0_col19,#T_2a19e_row2_col19,#T_2a19e_row5_col13,#T_2a19e_row5_col16{
#             background-color:  #f1e5e7;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col0,#T_2a19e_row16_col5{
#             background-color:  #e28799;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col2{
#             background-color:  #e28497;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col4,#T_2a19e_row11_col10,#T_2a19e_row16_col4,#T_2a19e_row19_col18{
#             background-color:  #de687f;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col5,#T_2a19e_row4_col7,#T_2a19e_row13_col11,#T_2a19e_row14_col17{
#             background-color:  #de667e;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col6{
#             background-color:  #db526e;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col7{
#             background-color:  #d83e5d;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col8,#T_2a19e_row11_col6,#T_2a19e_row17_col10{
#             background-color:  #e0768b;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col9,#T_2a19e_row1_col15,#T_2a19e_row13_col0,#T_2a19e_row13_col2,#T_2a19e_row16_col2{
#             background-color:  #db5872;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col10,#T_2a19e_row8_col18,#T_2a19e_row9_col15,#T_2a19e_row17_col0,#T_2a19e_row17_col2,#T_2a19e_row19_col11{
#             background-color:  #dc5c76;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col11,#T_2a19e_row8_col11,#T_2a19e_row11_col14,#T_2a19e_row13_col1{
#             background-color:  #e38d9e;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col12{
#             background-color:  #dd6179;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col13,#T_2a19e_row6_col4,#T_2a19e_row11_col0,#T_2a19e_row11_col2,#T_2a19e_row11_col18{
#             background-color:  #e18093;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col14,#T_2a19e_row4_col12,#T_2a19e_row15_col9{
#             background-color:  #efdcdf;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  10pt;
#         }#T_2a19e_row1_col

# %% [raw]
# WilmWidge = widgets.Dropdown(options=list(allWilm))
# #ClientWidge = widgets.Dropdown(options=geo[init])
# TypeWidge = widgets.Dropdown(options=list(allType ))
#
#
# # init2= cityW.value #new start value for district dropdown
# # districtW = widgets.Dropdown(options=geo2[init2]) #define district dropdown widget
#
# j = widgets.interactive(Above20orXIncrease, WILMORGNAME=cityW, Opportunities=districtW) #define district value
# i = widgets.interactive(select_city, country=scW)

# %%
class colour:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

print(colour.BOLD + 'Hello World !' + colour.END)
# Out:
# Hello World !

# %%
topclients=['KnowledgePool Group Ltd','BPP Professional Education Ltd','Barclays Bank PLC','Institute of Financial Services (IFS)','HSBC Bank Plc','Kaplan','Danske Bank','European Bank for Reconstruction and Development','Nordea Bank Abp, filial i Sverige','Capita Business Services Ltd','Nordea Danmark, filial af Nordea Bank Abp Finland','United Overseas Bank Ltd','Asian Institute of Chartered Bankers','Kuwait Chamber of Commerce & Industry','HSBC Bank PLC','Danq (Shanghai) Enterprise Development Ltd','KPMG LLP','Yorkshire Building Society','Public Bank Berhad','QA Limited','Orion Corporation','CSA (Services) Ltd','International Compliance Services LLC','Silicon Valley Bank','Galderma (UK) Ltd','The Malaysian Insurance Institute','KPMG Assurance Service Ltda','CIMB Investment Bank Berhad (Learning & Development)','DBS Bank Ltd','CLT International','PwC (Belfast Laganbank)','Harrods Limited','Dubai Financial Services Authority','Courses & Seminars Limited','NatWest PLC','Sean Tynan','Eversheds Sutherland LLP','Bank Simpanan Nasional','FSCom Limited','Stefan Rossi','IBF (Cambodia) Co., Ltd','European Investment Bank','Sovereign Trust (Isle of Man) Limited','Goh Yeow Hua','London Fire Brigade','Stephen Davies','Hill Dickinson LLP','Sim Yuan Xing','Nordea Bank Abp','Les Croupiers Casino','Lloyds Banking Group','Prashant Ganesanathan','GP Strategies Middle East Training LLC','Abacus Trust Company Ltd','Young & Partners Business Lawyers Ltd','Leong Hon Mun','Taylor Wessing LLP','Barclays Bank','TMF Group Fund Services (Jersey) Limited','Capita Plc','Synoption Pte Ltd','Basel Institute on Governance','Georgesons','RBS Services India Private Limited','Jitendra Maheshwari','Bayer PLC','PrimeQuotes LTD','Gibson & Associates Solicitors','Standard Chartered Bank Singapore','Morgan, Lewis & Bockius UK LLP','Financial Ombudsman Service','Mastercard Prepaid Management Services','Teva UK Limited','United Overseas Bank (Malaysia) Berhad','Boodle Hatfield LLP','Tokio Marine Kiln Singapore Pte Ltd','BIBF','Foo Shu Xuan Eileen','LOM FINANCIAL (BAHAMAS)LIMITED','NIIT Limited','Driver and Vehicle Standards Agency','Linklaters LLP','Merkur Zavarovalnica D. D.','Murray Waldren Consulting Pty Ltd','Nationwide Building Society','Special EU Programmes Body','Keith Bell','Ards and North Down Borough Council Accounts','Royal College of Physicians','Erynne Lim','Gohel Kaushalkumar Nirmalsinh','BNP Paribas Securities Services','Kingstons Will & Trust Planning Ltd','Thomson Snell & Passmore LLP','Cambia Health Solutions','White & Case LLP','Frontera Capital Group Limited','Arjay S/O Krishnan','Thomson Reuters Poland Sp. z o.o.','Marvin Hurlston','Nordea Bank Abp Poland Branch','Azets','Benjamin Foo Meng Chen','Parfrey Murphy & Co (Co. Cork)','Win Technologies','Sobia Khan','Franklins Solicitors LLP','Societe Generale','Mid Ulster District Council','Oversea-Chinese Banking Corporation Ltd','Smith Cooper IFS','Sampath Bank Plc','Azets Godalming','BMT Netherlands BV','SumUp Payments Limited, UK','Mishcon De Reya LLP','Ridouts Professional Services plc','Bibi Ahsha Choonarah','UHY Hacker Young','Apixio','Vodacom Lesotho','Healthspan Limited','Rabobank London','BANKA OTP ALBANIA SH.A','Ijapari Onolaja','UBS AG','Ministry of Justice','GP Strategies Poland sp.z.o.o','Elizabeth McGowan','BGL Group Limited','GP Strategies Limited','HFW','GP Strategies Hong Kong Limited','Willoughby Corporate Services Ltd','Refinitiv','Cohen Arnold','S Stromp','Sparkling Consultancy PTE Ltd','Speirs & Jeffrey Ltd','Standard Chartered Bank (Singapore) Limited','C Campbell','Mason Hayes & Curran','Freemarket Fx','MRO Accounts Limited','Wong Mei Teng','Koh Kai Keong, Edwin','Hart Shaw LLP','Luminor Bank AS','Jones Whyte LLP','ASN Partnership Ltd','TransferWise Ltd','Warners Solicitors LLP','Wong Wai Shan Anita','Law Trust Switzerland AG','Neath Port Talbot County Borough Council','Tong Qiao E','Chapman Freeborn International','KPMG AG','Sibonile Mhlope','Barclays Bank Plc','Sri Nur Dalilah Binte Ahmad','Hewitsons LLP','David Andrew Jones','Channel Islands Financial Ombudsman (CIFO)','Jacqueline Besem Iyok Egbe','Nicky Wee Wei Ming','Russell & Co','Peyton Tyler Mears','Chew Yihao','Trowers & Hamlins (Services)','Praxis Trust Ltd','Lam King Hei','Athona Limited','BT','JDB Chartered Certified Accountants','Guernsey Financial Services Commission','South Eastern Trust','Danone Holdings (UK)','Reliance Solicitors','Thomas Mifsud-Tommasi','Jupiter Travels & Tours Pte Ltd','First Abu Dhabi Bank','North Hertfordshire District Council','Sohail  Akbar','National Westminister Bank Plc (PL)','Matt Caro','Shepherd & Wedderburn LLP','Richard Dunlop','Suntera (IOM) Limited','C Lambert','Wendy Tan Sok Yi','Environment Agency','First Heartland Capital JSC','CJC Advisors SA','Ahad Parekh','PraxisIFM Trust Limited','ASOCIACIÄ‚Â“N EUROPEA DE ABOGADOS Y ECONOMISTAS EN COMPLIANCE(AEAEC)','Thompson Mitchell Solicitors','Alcina Tan Si Ning','HSBC Bank plc, Jersey Branch','Zafar Anjum','Newport City Council','Farooq Law Solicitors','Victim Focus','Handelsbanken Plc','Blackadders LLP','Caroline Bugendage Ogwang','Kent Surrey and Sussex Community Rehabilitation Company','Leticia Osei','Generali Å»ycie Towarzystwo UbezpieczeÅ„ S.A','Isma Ali','International In-House Counsel Journal Limited','E&K Solicitors']
TopOp = ["Barclays- Mixed Qualifications","SVB Various Qualifications","IMB BPP/RBS Online Diplomas - Level 6","PGO GRC Jacqueline Besem Iyok Egbe","IMB/IHC/IHA Danske Autumn intake - Marija - Compliance Team","SG Inhouse (UOB) - ICA Advanced Certificate in RC - June 2020","LEU YI LING EILEEN - Adv Cert GRC","FOO SHU XUAN EILEEN (HU SHUXUAN) - Adv Cert GRC","ZZZ - Nordea Sweden - online/in-house","IAH - HSBC - Various Qualifications (Caroline Edwards) 3/4","IME Joanna Simon","PGO GRC zoe allen-robinson","Credit Of W-1108157 IHC-PWC-Online","Credit Of W-928273 INH - RBSI - Adv AML - Jonathan Kennaugh's Booking","ICE Chris Metters","PGO FCC Bernardette Hoffman","ICE Amelia Frost","IMB BPP/RBS Apprentices TBC","Credit Of W-768307 Ritsons - PT Annual DD - Oct 19","Jacqueline Sherlock - SEE - Res Con","KWOK MEI HENG - Dip AML/CFT M4","EDRIC WONG TSEH FOON (EDRIC HUANG ZEFENG) - Adv Cert RC (FC)","TANG YEW LEONG - Adv Cert GRC","IMB-QA/Santander-UK","DDC Al Baraka Bank (8VC) x 17","POS FCC John Osei-Kwaku","ANG GHIM THONG (HONG JINTONG) - Dip AML/CFT M5","Marco Benedetti - SPD - Company Law","Credit Of W-854544 ZZZ/INH - Various courses - Revolut-London","Credit Of W-809612 Orion Corporation Q1 2020","Credit Of W-1041744 2021 - Admin of Estates and Admin of Trusts","ICE Kaplan D.Goddard","PGO GRC Kostyantyn Mukhlygin","IDL AnaÃ¯s Mekki","KHOO WEI TING - Adv Cert RC","PGO FCC Lisa Peele","ERROR","IDL Samee Abraham Yu Wei Chun","ICK Lauren McKinley","Galderma Nordic IM Application Suite Q3 2018","IAH-IHC-HSBC BIRMINGHAM+LONDON","IME Rebecca Duke","IDL Rosemary Hilekaan","IME Elena Alice Stockwel","LILIAN LIEW SU CHUI - Adv Cert GRC","Sophie Clifford - SPD - Res Con","IAM - Martin Logar","IME David Andrew Jones","ZZZ-Investec-UK","IDL Lucette Guzdar","5x TCPD bookings for Thomas McMurtrie","PGO FCC Spyridon Roumaneas","Credit Of W-1087250 CREDITED SF ERROR - IHA - EBRD Uzbekistan - Spec Cert FCRGB","Credit Of W-1076901 IHC - Danske Spring 2021 - Ruta - Lithuania - Ieva and Justyna Cancelled","Credit Of W-626265 Nov - Cert - Manchester - Azmoodeh","PGO FCC Elizabeth Travis","Credit Of W-592854 Hardev Gill-CUBS- 3/6/19","Credit Of W-499581 ASM Technologies Ltd - Wilmington Healthcare - 18/12/2018","IMO Martina Blandi","Credit Of W-856544 IMB-Kaplan/Barclays-Glasgow App","Nov 20- Family Business package-Osborne","PGO FCC Adam Evans","PGO FCC Nicola Passariello","PGO FCC - Viviane Giglio","PGO FCC - Cyril Esterhuysen","Certification in RC - Aug 2018 KL - MII","ICK Victoria Coombe","ANIL KUMAR ARORA - Dip AML/CFT M3","GOHEL KAUSHALKUMAR NIRMALSINH - Adv Cert RC (FC)","Credit Of W-404760 Renewal of CSM Licence","I Westheim - AML F2F Diploma Oct 18 - SEpt 18","Credit Of W-896039 ER SAI Caspian Reinvoice Morgan Lewis - Khazakstan","Credit Of W-831210 IMO-Kyoko Wynn-","Credit Of W-849715 CLT Individual Membership Â£249","WEE ZHIYUAN ROY (HUANG ZHIYUAN ROY) - Dip FCC M2","Resit Fee - International Trust Management - Exam","Credit Of W-614723 Dec 19-VC-Davison","Credit Of W-1026415 2021 - Diploma 1 and 2 - UK and CD - Wall","Credit Of W-889303 CLI_215698_DAN_WANG","IDL Asheed Thomas","CLI_215238_Edwards","IDL Anders Rechendorff","IMO Tracey Simmons","P Finn - AML F2F Diploma Oct 19","July 18-IH-Dip GRC-Germany","ICO Agnieszka Wankowicz","CLEMENT TEE BOO SONG - Dip GRC M2","Credit Of W-1041520 FCO - KP/RBS - V.Ogodo Onasanya","INH - Various - Nordea - Poland - Spring 2021","INH - IMB - Nordea - Poland - Autumn 2020 - student defer","IHC Societe Generale Bangalore","ICO Helen Roberts","CHUA MENG CHOO - ICA Certificate in Anti Money Laundering - 7 & 8 September 2020","ILO -Cary Whitmarsh","Credit Of W-898007 Advanced Cert CDD- TMF Group-  Jersey","IHD - HSBC - Diploma - second opp","IMO/ICO RBS India Online Diploma/Adv Cert","INH - IHA/IMB - Nordea - Denmark - Autumn 2020","IHC Citi Bank Warsaw X3 additions","IDL David Wigg","IDL Deepa Jivan","CLI_226013_Auguste_Dronseikaite","Oct 18 IH Lloyds Bank Adv Cert AML & Adv Cert MSR","Oct 18 Barclays - Adv Cert/Dip in AML NEW","Credit Of W-863720 EMAIL MANUALLY re-inivoice opp Yasmin Akhtar - CHIA Public","Credit Of W-810513 Kylie Tanner - CUBS","Barron & Co-Practice Assurance Compliance Manual-21/06/2021 00:00:00","CLI_229257_R&H_Trust_Co_(Jersey)_Limited","Credit Of W-703556 SC (JI) Belfast Trust and Southern Trust - 24th Sept - 9th O","Credit Of W-1067202 WFF Public - Welsh Gov - APCIP (x2)","Barclays - Mixed Qualifications NEW OPP","Credit Of W-914761 IMB RBS/Natwest Poland - additional student","YOUNG KUAN YEW, ARTHUR - Dip GRC M4","CCO Victoria Coleman","Credit Of W-1025113 CC Carol Rabet - Public Chia - March","LOW LIFENG - Dip GRC M2","CEO Damian Susel","IMB BPP/RBS Apprentices - Online","Credit Of W-764196 IMB-Jersey Police-Jersey","WAN CHI HONG - Int Dip AML (HK) - April 2019","Credit Of W-1025067 CLI_227467_Athena_Probate","Credit Of W-1025095 IHA - SWIFT KL- Cert KYC/CDD","Credit Of W-1054467 IHC - HMRC Adv Cert AML 1/2","FCO Craig Gauvain","FCO BERTINA HAJDINI","2021 - PPgD - Hungary - Ulmann","TEO PUI HOON (ZHANG PEIFEN) - Dip AML/CFT M4","Credit Of W-613724 May 19-Dip 3-Cayman-Anderson","PGO GRC Eliaser Iiyambo","Nov 18-Foundations-Chang","POS GRC Anzhela Pradun","IFA Sarah Blackman","COM - Renewal - Lloyds Banking Group - ICA - 12/11/2020","EY (Ernst & Young LLP) - COM renewal 2020-2021","IML Patrick Seidu","DDC Sohail  Akbar","2 x TCPD Bookings for Mariel Kaney","POS FCC Thamer Faraj -Al- Hazmi","S McGorrian - AML DL Diploma Feb 2019 - Mar 2019","Credit Of W-903827 Dyson - APCIP - Public (x2) - Ceri McQueen and James Wilson","Carolann Chalmers - SPD - Res Con","Credit Of W-534113 SC Remove two ZERO LINES before posting JI London Borough of","cancelled IDL Richard Evan Jones","POS FCC Marisa Frendo","DAM Mohamed Fouad","IMO Guruge Viraj Dharmasiri","Advanced Certs x 8- Lot Payments","POS GRC Dauren Akshalov","IML Gary Curtis","IMO Chantell Debattista","IMO Anne Scott","ADK Mohammed Al Khoudary","CUC Abshir Hussein","Credit Of W-584761 ICE Justin Bentley","IFC Sarah Booth","Final Invoice EBRD 2018 Contract","IBO Filiz Hazir","POS GRC Toritseju Agoro","POS GRC Desere Attard","Credit Of W-783363 Feb 20 - Cert - Geneva - Sigg","Credit Of W-861109 Phil Briggs - Civil CUBS - (April 2020 - October 2020)","Credit Of W-858622 Sept 20-Dip.4-AB Green","Adv Certificate in Regulatory Compliance - Oct 2018 KL (Grp 1 & Grp 2)","Credit Of W-618323 SC EMAIL 3PP(JI) Hywel Dda University Health Board - Serious","IFC Anthony Minshull","POS GRC Haroon Khan","Credit Of W-834711 IMB BPP/RBS Apprentices TBC","Orion Corporation Q1 2020","PGO GRC Jalinka Strachan","IHA/IHC/IMB RBS/Natwest Poland Various - PART 1","Credit Of W-912015 IFC - Barclays Bank - C.Fitzharris","Credit Of W-1107326 IHC - HMRC Adv Cert AML 2/2","TD INVOICE ONLY - Nationwide Building Society - 1/2nd October","Credit Of W-617502 LMDB Payroll LLP - Mercia TC 19/20 Run 3","Credit Of W-773472 Communities NI- 2 X APCIP Public","KENIX CHAN - Hong Kong Int Dip AML - Resit","Credit Of W-894736 Nov.20-Trusts-London-Shangari","Nov 19 - Uk Tax - Geneva - Zeller","ICE Ruth Caine","ICE Michael Lewis","Credit Of W-810784 Clifford Roberts - PT Annual DD - Jan 20","IHA/IHC - FOS - Online Additional.6","IDL- Tracey Ford","IMO Lara Jo Portelli","Credit Of W-712529 Mark Weal- CUBB- 1/7/19"]

# %%
clientBox = pn.widgets.MultiSelect(name = 'Client Multi-Select:',
    value=list(allClients),
    placeholder='Choose Someone',
    options=['KnowledgePool Group Ltd','BPP Professional Education Ltd','Barclays Bank PLC','Institute of Financial Services (IFS)','HSBC Bank Plc','Kaplan','Danske Bank','European Bank for Reconstruction and Development','Nordea Bank Abp, filial i Sverige','Capita Business Services Ltd','Nordea Danmark, filial af Nordea Bank Abp Finland','United Overseas Bank Ltd','Asian Institute of Chartered Bankers','Kuwait Chamber of Commerce & Industry','HSBC Bank PLC','Danq (Shanghai) Enterprise Development Ltd','KPMG LLP','Yorkshire Building Society','Public Bank Berhad','QA Limited','Orion Corporation','CSA (Services) Ltd','International Compliance Services LLC','Silicon Valley Bank','Galderma (UK) Ltd','The Malaysian Insurance Institute','KPMG Assurance Service Ltda','CIMB Investment Bank Berhad (Learning & Development)','DBS Bank Ltd','CLT International','PwC (Belfast Laganbank)','Harrods Limited','Dubai Financial Services Authority','Courses & Seminars Limited','NatWest PLC','Sean Tynan','Eversheds Sutherland LLP','Bank Simpanan Nasional','FSCom Limited','Stefan Rossi','IBF (Cambodia) Co., Ltd','European Investment Bank','Sovereign Trust (Isle of Man) Limited','Goh Yeow Hua','London Fire Brigade','Stephen Davies','Hill Dickinson LLP','Sim Yuan Xing','Nordea Bank Abp','Les Croupiers Casino','Lloyds Banking Group','Prashant Ganesanathan','GP Strategies Middle East Training LLC','Abacus Trust Company Ltd','Young & Partners Business Lawyers Ltd','Leong Hon Mun','Taylor Wessing LLP','Barclays Bank','TMF Group Fund Services (Jersey) Limited','Capita Plc','Synoption Pte Ltd','Basel Institute on Governance','Georgesons','RBS Services India Private Limited','Jitendra Maheshwari','Bayer PLC','PrimeQuotes LTD','Gibson & Associates Solicitors','Standard Chartered Bank Singapore','Morgan, Lewis & Bockius UK LLP','Financial Ombudsman Service','Mastercard Prepaid Management Services','Teva UK Limited','United Overseas Bank (Malaysia) Berhad','Boodle Hatfield LLP','Tokio Marine Kiln Singapore Pte Ltd','BIBF','Foo Shu Xuan Eileen','LOM FINANCIAL (BAHAMAS)LIMITED','NIIT Limited','Driver and Vehicle Standards Agency','Linklaters LLP','Merkur Zavarovalnica D. D.','Murray Waldren Consulting Pty Ltd','Nationwide Building Society','Special EU Programmes Body','Keith Bell','Ards and North Down Borough Council Accounts','Royal College of Physicians','Erynne Lim','Gohel Kaushalkumar Nirmalsinh','BNP Paribas Securities Services','Kingstons Will & Trust Planning Ltd','Thomson Snell & Passmore LLP','Cambia Health Solutions','White & Case LLP','Frontera Capital Group Limited','Arjay S/O Krishnan','Thomson Reuters Poland Sp. z o.o.','Marvin Hurlston','Nordea Bank Abp Poland Branch','Azets','Benjamin Foo Meng Chen','Parfrey Murphy & Co (Co. Cork)','Win Technologies','Sobia Khan','Franklins Solicitors LLP','Societe Generale','Mid Ulster District Council','Oversea-Chinese Banking Corporation Ltd','Smith Cooper IFS','Sampath Bank Plc','Azets Godalming','BMT Netherlands BV','SumUp Payments Limited, UK','Mishcon De Reya LLP','Ridouts Professional Services plc','Bibi Ahsha Choonarah','UHY Hacker Young','Apixio','Vodacom Lesotho','Healthspan Limited','Rabobank London','BANKA OTP ALBANIA SH.A','Ijapari Onolaja','UBS AG','Ministry of Justice','GP Strategies Poland sp.z.o.o','Elizabeth McGowan','BGL Group Limited','GP Strategies Limited','HFW','GP Strategies Hong Kong Limited','Willoughby Corporate Services Ltd','Refinitiv','Cohen Arnold','S Stromp','Sparkling Consultancy PTE Ltd','Speirs & Jeffrey Ltd','Standard Chartered Bank (Singapore) Limited','C Campbell','Mason Hayes & Curran','Freemarket Fx','MRO Accounts Limited','Wong Mei Teng','Koh Kai Keong, Edwin','Hart Shaw LLP','Luminor Bank AS','Jones Whyte LLP','ASN Partnership Ltd','TransferWise Ltd','Warners Solicitors LLP','Wong Wai Shan Anita','Law Trust Switzerland AG','Neath Port Talbot County Borough Council','Tong Qiao E','Chapman Freeborn International','KPMG AG','Sibonile Mhlope','Barclays Bank Plc','Sri Nur Dalilah Binte Ahmad','Hewitsons LLP','David Andrew Jones','Channel Islands Financial Ombudsman (CIFO)','Jacqueline Besem Iyok Egbe','Nicky Wee Wei Ming','Russell & Co','Peyton Tyler Mears','Chew Yihao','Trowers & Hamlins (Services)','Praxis Trust Ltd','Lam King Hei','Athona Limited','BT','JDB Chartered Certified Accountants','Guernsey Financial Services Commission','South Eastern Trust','Danone Holdings (UK)','Reliance Solicitors','Thomas Mifsud-Tommasi','Jupiter Travels & Tours Pte Ltd','First Abu Dhabi Bank','North Hertfordshire District Council','Sohail  Akbar','National Westminister Bank Plc (PL)','Matt Caro','Shepherd & Wedderburn LLP','Richard Dunlop','Suntera (IOM) Limited','C Lambert','Wendy Tan Sok Yi','Environment Agency','First Heartland Capital JSC','CJC Advisors SA','Ahad Parekh','PraxisIFM Trust Limited','ASOCIACIÄ‚Â“N EUROPEA DE ABOGADOS Y ECONOMISTAS EN COMPLIANCE(AEAEC)','Thompson Mitchell Solicitors','Alcina Tan Si Ning','HSBC Bank plc, Jersey Branch','Zafar Anjum','Newport City Council','Farooq Law Solicitors','Victim Focus','Handelsbanken Plc','Blackadders LLP','Caroline Bugendage Ogwang','Kent Surrey and Sussex Community Rehabilitation Company','Leticia Osei','Generali Å»ycie Towarzystwo UbezpieczeÅ„ S.A','Isma Ali','International In-House Counsel Journal Limited','E&K Solicitors']
    ,description='Combobox:',
    ensure_option=True,
    disabled=False
) 

WilmBox = pn.widgets.MultiSelect(name = colour.RED + 'Wilmington Organisation Multi-Select:' + colour.END,
    value=list(allWilm),
    placeholder='Choose Someone',
    options= list(allWilm)   
    ,description='Combobox:',
    ensure_option=True,
    disabled=False
) 


TypeBox = pn.widgets.MultiSelect(name = 'Type Multi-Select:',
    value=list(allType),
    placeholder='Choose Someone',
    options= list(allType)   
    ,description='Combobox:',
    ensure_option=True,
    disabled=False
) 


OppBox = pn.widgets.MultiSelect(name = 'Opportunity Multi-Select:',
    value=list(allOpps),
    options= TopOp   
) 


MinRevenuePercent = pn.widgets.FloatSlider(start=0, end=100, step=0.01, value=0, name =  'Percent Revenue Floor:')
MinRevenue = pn.widgets.FloatSlider(start=bas.REVENUE.min(), step=0.01, end=bas.REVENUE.max(), value=0, name =  'Absolute Revenue Floor:')
weekToComplete = pn.widgets.FloatSlider(start=bas.WEEK.min(), step=0.01, end=bas.WEEK.max(), value=0, name =  'Weeks to production Floor:')

factor_select = pn.widgets.MultiSelect(name='Factors for Correction', value=basNum,
    options=basNum, size=8)


display(pn.Row(WilmBox, clientBox, TypeBox, OppBox, factor_select))
display(pn.Row(MinRevenue_slider, MinRevenuePercent_slider, WEEKToComplete))
# Out:
# WARNING:param.Client Multi-Select:: Setting non-parameter attribute placeholder=Choose Someone using a mechanism intended only for parameters
# WARNING:param.Client Multi-Select:: Setting non-parameter attribute description=Combobox: using a mechanism intended only for parameters
# WARNING:param.Client Multi-Select:: Setting non-parameter attribute ensure_option=True using a mechanism intended only for parameters
# WARNING:param.Wilmington Organisation Multi-Select:: Setting non-parameter attribute placeholder=Choose Someone using a mechanism intended only for parameters
# WARNING:param.Wilmington Organisation Multi-Select:: Setting non-parameter attribute description=Combobox: using a mechanism intended only for parameters
# WARNING:param.Wilmington Organisation Multi-Select:: Setting non-parameter attribute ensure_option=True using a mechanism intended only for parameters
# WARNING:param.Type Multi-Select:: Setting non-parameter attribute placeholder=Choose Someone using a mechanism intended only for parameters
# WARNING:param.Type Multi-Select:: Setting non-parameter attribute description=Combobox: using a mechanism intended only for parameters
# WARNING:param.Type Multi-Select:: Setting non-parameter attribute ensure_option=True using a mechanism intended only for parameters
# Row
#     [0] MultiSelect(name='\x1bWilmington O..., options=['ICA Commercial Services ...], value=['ICA Commercial Services ...])
#     [1] MultiSelect(name='Client Multi-Select:', options=['KnowledgePool Group Ltd'...], value=['KnowledgePool Group Ltd'...])
#     [2] MultiSelect(name='Type Multi-Select:', options=['New Business', ...], value=['New Business', ...])
#     [3] MultiSelect(name='Opportunity M..., options=['Barclays- Mixed Qualific...], value=['PGO GRC Jalinka Strachan...])
#     [4] MultiSelect(name='Factors for Correction', options=['AMOUNT', 'CREDITNOTETOTA...], size=8, value=['AMOUNT', 'CREDITNOTETOTA...])
# Row
#     [0] FloatSlider(end=100, name='Absolute Revenue Floor', step=0.01)
#     [1] FloatSlider(name='Percent Revenue Floor', start=-665659.0, step=0.01)
#     [2] FloatSlider(end=385.85714285714283, name='Weeks to production F..., start=-155.0, step=0.01)

# %%
Above20orXIncrease(ClientOrg = clientBox.value, Type = TypeBox.value, MinWeeksToComplete = weekToComplete.value,  WILMORGNAME = allWilm, Opportunities = OppBox.value, TargetMinRevenue =MinRevenue_slider.value, TargetMinPercentRevenue = MinRevenuePercent_slider.value, forCorr = factor_select.value)
# Out:
# Likely Revenue Given Input: 18244.86     Average Opportunity Revenue: 3845.99     Average vs Likely (% Difference): 374.39
# ---------------------------------------------------------------------------------------------------------
# Features that have given a Revenue above target absolute and percentage revenue with selected dimensions:
#         Wilm Orgs Meeting Targets, ranked by revenue  Average Revenue
# 4  International Compliance Training Academy Pte Ltd    145446.998276
# 1                        ICA Commercial Services Ltd     47420.871278
# 2         International Compliance Association (ICA)     32930.300000
# 5                          Wilmington Healthcare Ltd      8101.320000
# 0                                         Bond Solon      4914.900000
# 3         International Compliance Training (ME) Ltd      3163.333333
#   Opportunity types meeting Targets, ranked  Average Revenue
# 0                              New Business      55591.20567
# 1                                   Renewal      32930.30000
# 2                           Repeat Business       8101.32000
#   Divisions Meeting Targets, ranked  Average Revenue
# 2                 Risk & Compliance     55504.814688
# 0                        Healthcare      8101.320000
# 1                      Professional      4914.900000
#                       Clients Meeting Targets, ranked  Average Revenue
# 0                Asian Institute of Chartered Bankers    280000.000000
# 37                           United Overseas Bank Ltd    167670.000000
# 2                      BPP Professional Education Ltd    118854.790419
# 7                                         Danske Bank     81515.210000
# 31                                         QA Limited     55855.000000
# 27                  Nordea Bank Abp, filial i Sverige     54696.000000
# 33                                Silicon Valley Bank     54198.000000
# 3                                       Barclays Bank     51750.000000
# 14                                      HSBC Bank Plc     46479.814815
# 24                National Westminister Bank Plc (PL)     45510.000000
# 4                                   Barclays Bank PLC     38692.142857
# 20                            KnowledgePool Group Ltd     34138.372093
# 22                               Lloyds Banking Group     32930.300000
# 13                                      HSBC Bank PLC     27600.000000
# 28  Nordea Danmark, filial af Nordea Bank Abp Finland     19738.000000
# 32                 RBS Services India Private Limited     17250.000000
# 26                      Nordea Bank Abp Poland Branch     16119.651163
# 36                  The Malaysian Insurance Institute     12946.950000
# 30                                    PrimeQuotes LTD     12070.000000
# 29                                  Orion Corporation      8101.320000
# 35                         SumUp Payments Limited, UK      7495.000000
# 11                      Gohel Kaushalkumar Nirmalsinh      6900.000000
# 6                                        DBS Bank Ltd      6900.000000
# 23             Mastercard Prepaid Management Services      6745.500000
# 18                         Jacqueline Besem Iyok Egbe      6370.750000
# 17              International Compliance Services LLC      4967.000000
# 25                        Nationwide Building Society      4914.900000
# 34                                      Sohail  Akbar      4400.000000
# 10                      GP Strategies Poland sp.z.o.o      3600.000000
# 16              Institute of Financial Services (IFS)      3471.896552
# 5                      Chapman Freeborn International      3450.000000
# 12             Guernsey Financial Services Commission      3450.000000
# 8                                  David Andrew Jones      3450.000000
# 15                                  Handelsbanken Plc      3450.000000
# 19                                             Kaplan      3450.000000
# 21              Kuwait Chamber of Commerce & Industry      1750.000000
# 1                                   BGL Group Limited      1725.000000
# 9    European Bank for Reconstruction and Development       600.000000
# ---------------------------------------------------------------------------------------------------------
# Unique combinations of features with a Revenue above set revenue targets and within combinations:
# ---------------------------------------------------------------------------------------------------------
# Correlaton between selected dimensions converted to numeric format, and measures, with selected dimensions:
#                      AMOUNT  CREDITNOTETOTAL   REVENUE  COST  UNITPRICE  \
# AMOUNT             1.000000         0.005556  0.876405   NaN  -0.011263
# CREDITNOTETOTAL    0.005556         1.000000  0.029431   NaN  -0.049850
# REVENUE            0.876405         0.029431  1.000000   NaN  -0.072726
# COST                    NaN              NaN       NaN   1.0        NaN
# UNITPRICE         -0.011263        -0.049850 -0.072726   NaN   1.000000
# PIPETIMED          0.102231         0.009652  0.118234   NaN   0.047343
# TIMEVAL            0.623582        -0.000879  0.596271   NaN  -0.030898
# CREDITVAL          0.332746        -0.449963  0.343185   NaN  -0.022144
# WILMORGNAMECODELE -0.049923        -0.174981 -0.133576   NaN   0.011711
# CLIENTORGLE       -0.017174        -0.041949 -0.092573   NaN  -0.007102
# OPPORTUNITYNAMELE  0.097216        -0.083388  0.076536   NaN  -0.055256
# PRODUCTNAMELE     -0.151485        -0.062912 -0.183527   NaN   0.036875
# STAGENAMELE        0.150388        -0.035111  0.106513   NaN  -0.062920
# FISCALQUARTERLE    0.148571         0.177056  0.133173   NaN  -0.062427
# TYPELE             0.100705        -0.098363 -0.130684   NaN   0.300529
# CREATEDDATELE     -0.003628         0.022996 -0.016802   NaN  -0.082288
# CLOSEDTLE          0.141985         0.162801  0.126041   NaN  -0.047693
# PIPETIMELE        -0.201758        -0.148540 -0.184403   NaN  -0.012867
# WILMDIVISIONLE    -0.083026         0.167289  0.145463   NaN  -0.244347
# WILMORGNAMELE      0.228036         0.065750  0.107402   NaN   0.063339
#
#                    PIPETIMED   TIMEVAL  CREDITVAL  WILMORGNAMECODELE  \
# AMOUNT              0.102231  0.623582   0.332746          -0.049923
# CREDITNOTETOTAL     0.009652 -0.000879  -0.449963          -0.174981
# REVENUE             0.118234  0.596271   0.343185          -0.133576
# COST                     NaN       NaN        NaN                NaN
# UNITPRICE           0.047343 -0.030898  -0.022144           0.011711
# PIPETIMED           1.000000 -0.275124   0.040452           0.173885
# TIMEVAL            -0.275124  1.000000   0.290854          -0.044407
# CREDITVAL           0.040452  0.290854   1.000000           0.172850
# WILMORGNAMECODELE   0.173885 -0.044407   0.172850           1.000000
# CLIENTORGLE        -0.472552  0.110366   0.078285          -0.142601
# OPPORTUNITYNAMELE  -0.415038  0.215648   0.135736           0.030228
# PRODUCTNAMELE       0.007041 -0.125798  -0.004182           0.373903
# STAGENAMELE        -0.315614  0.274612   0.192499          -0.112447
# FISCALQUARTERLE     0.178633  0.197379  -0.014724           0.036209
# TYPELE             -0.012903  0.097889  -0.038097           0.001309
# CREATEDDATELE      -0.726446  0.337834  -0.007517          -0.173913
# CLOSEDTLE           0.216694  0.195841   0.000251           0.081518
# PIPETIMELE          0.090189  0.027289   0.011579           0.162236
# WILMDIVISIONLE      0.097448 -0.075248   0.114211          -0.205696
# WILMORGNAMELE      -0.255842  0.223585  -0.114487          -0.553517
#
#                    CLIENTORGLE  OPPORTUNITYNAMELE  PRODUCTNAMELE  STAGENAMELE  \
# AMOUNT               -0.017174           0.097216      -0.151485     0.150388
# CREDITNOTETOTAL      -0.041949          -0.083388      -0.062912    -0.035111
# REVENUE              -0.092573           0.076536      -0.183527     0.106513
# COST                       NaN                NaN            NaN          NaN
# UNITPRICE            -0.007102          -0.055256       0.036875    -0.062920
# PIPETIMED            -0.472552          -0.415038       0.007041    -0.315614
# TIMEVAL               0.110366           0.215648      -0.125798     0.274612
# CREDITVAL             0.078285           0.135736      -0.004182     0.192499
# WILMORGNAMECODELE    -0.142601           0.030228       0.373903    -0.112447
# CLIENTORGLE           1.000000           0.461054      -0.069705     0.288722
# OPPORTUNITYNAMELE     0.461054           1.000000       0.100494     0.349598
# PRODUCTNAMELE        -0.069705           0.100494       1.000000     0.055089
# STAGENAMELE           0.288722           0.349598       0.055089     1.000000
# FISCALQUARTERLE       0.071570           0.046151      -0.061122    -0.017398
# TYPELE                0.127142          -0.000221       0.014284     0.077631
# CREATEDDATELE         0.445923           0.467211      -0.026593     0.430299
# CLOSEDTLE             0.037279          -0.013582      -0.032133    -0.007781
# PIPETIMELE           -0.079719          -0.105679       0.113054     0.038902
# WILMDIVISIONLE       -0.130468          -0.137338      -0.130351    -0.063606
# WILMORGNAMELE         0.218008           0.006493      -0.312996     0.138446
#
#                    FISCALQUARTERLE    TYPELE  CREATEDDATELE  CLOSEDTLE  \
# AMOUNT                    0.148571  0.100705      -0.003628   0.141985
# CREDITNOTETOTAL           0.177056 -0.098363       0.022996   0.162801
# REVENUE                   0.133173 -0.130684      -0.016802   0.126041
# COST                           NaN       NaN            NaN        NaN
# UNITPRICE                -0.062427  0.300529      -0.082288  -0.047693
# PIPETIMED                 0.178633 -0.012903      -0.726446   0.216694
# TIMEVAL                   0.197379  0.097889       0.337834   0.195841
# CREDITVAL                -0.014724 -0.038097      -0.007517   0.000251
# WILMORGNAMECODELE         0.036209  0.001309      -0.173913   0.081518
# CLIENTORGLE               0.071570  0.127142       0.445923   0.037279
# OPPORTUNITYNAMELE         0.046151 -0.000221       0.467211  -0.013582
# PRODUCTNAMELE            -0.061122  0.014284      -0.026593  -0.032133
# STAGENAMELE              -0.017398  0.077631       0.430299  -0.007781
# FISCALQUARTERLE           1.000000  0.025663       0.095401   0.952820
# TYPELE                    0.025663  1.000000       0.037788   0.033253
# CREATEDDATELE             0.095401  0.037788       1.000000   0.070061
# CLOSEDTLE                 0.952820  0.033253       0.070061   1.000000
# PIPETIMELE                0.004076  0.074559       0.135888   0.061551
# WILMDIVISIONLE            0.123231 -0.597498      -0.057333   0.119838
# WILMORGNAMELE            -0.049323  0.489389       0.269954  -0.095979
#
#                    PIPETIMELE  WILMDIVISIONLE  WILMORGNAMELE
# AMOUNT              -0.201758       -0.083026       0.228036
# CREDITNOTETOTAL     -0.148540        0.167289       0.065750
# REVENUE             -0.184403        0.145463       0.107402
# COST                      NaN             NaN            NaN
# UNITPRICE           -0.012867       -0.244347       0.063339
# PIPETIMED            0.090189        0.097448      -0.255842
# TIMEVAL              0.027289       -0.075248       0.223585
# CREDITVAL            0.011579        0.114211      -0.114487
# WILMORGNAMECODELE    0.162236       -0.205696      -0.553517
# CLIENTORGLE         -0.079719       -0.130468       0.218008
# OPPORTUNITYNAMELE   -0.105679       -0.137338       0.006493
# PRODUCTNAMELE        0.113054       -0.130351      -0.312996
# STAGENAMELE          0.038902       -0.063606       0.138446
# FISCALQUARTERLE      0.004076        0.123231      -0.049323
# TYPELE               0.074559       -0.597498       0.489389
# CREATEDDATELE        0.135888       -0.057333       0.269954
# CLOSEDTLE            0.061551        0.119838      -0.095979
# PIPETIMELE           1.000000       -0.068162      -0.001431
# WILMDIVISIONLE      -0.068162        1.000000      -0.205696
# WILMORGNAMELE       -0.001431       -0.205696       1.000000

# %%
from IPython.html import widgets
from IPython.display import display

geo={'USA':['CHI','NYC'],'Russia':['MOW','LED']}

geo2={'CHI':['1','2'],'NYC':['3','4'],'MOW':['5','6'],'LED':['7','8']} #create dictionary with city districts

def print_city(city,district):
    print(city)
    print(district) #add in command to print district

def select_city(country):
    cityW.options = geo[country]

#add in 'select district' function that looks in the new dictionary
def select_district(city):
    districtW.options = geo2[city]

scW = widgets.Dropdown(options=geo.keys())
init = scW.value
cityW = widgets.Dropdown(options=geo[init])


init2= cityW.value #new start value for district dropdown
districtW = widgets.Dropdown(options=geo2[init2]) #define district dropdown widget

j = widgets.interactive(print_city, city=cityW, district=districtW) #define district value
i = widgets.interactive(select_city, country=scW)

k = widgets.interactive(select_district, city=cityW) #call everything together with new interactive

display(i)
display(j)

# %%
CorMap(FeaturesToCorrelate = multi_select.value)

# %%
widgets.Text(
    value='BPP Professional Education Ltd',
    placeholder='Type something',
    description='String:',
    disabled=False
)

# %%
(bas.CLIENTORG.unique())

# %%
bas.CLIENTORG.value_counts()#.to_csv(r'VCClientOrg.csv')

# %%
# %pwd

# %%
w = widgets.SelectMultiple(CorMap,FeaturesToCorrelate=bas.select_dtypes(np.number).columns)

# %%
bas.COST

# %%
bas.select_dtypes(np.number).columns

# %%
def func1(x):
    return 5*x
interact(func1, x=10);

# %%
bas.REVENUE.max()

# %%
w = interactive(Above20orXIncrease, TargetMinPercentRevenue = widgets.IntSlider(min=-665659.0, max=750000.0, value=25, step=10000)) 
#                         b=widgets.IntSlider(min=10, max=50, value=25, step=2),
#                         c=widgets.IntSlider(min=10, max=50, value=25, step=2),
#                        )
display(w)
# Above20orXIncrease(TargetMinPercentRevenue = 130, MinWEEKsToComplete = 40)#, WILMORGNAME = ['ICA']) #Opportunities=['Credit Of W-1113094 Various HMRC remaining licenses'], , TargetMinRevenue = 1265.88,  TargetMinPercentRevenue = 120)                

# Above20orXIncrease(TargetMinPercentRevenue = 130, 
#                    MinWEEKsToComplete = 40)#, WILMORGNAME = ['ICA']) #Opportunities=['Credit Of W-1113094 Various HMRC remaining licenses'], , TargetMinRevenue = 1265.88,  TargetMinPercentRevenue = 120)

# %%
interact(CorMap, FeaturesToCorrelate=['WILMDIVISIONLE', 'WILMORGNAMELE', 'CLIENTORGLE', 'OPPORTUNITYNAMELE',
       'STAGENAMELE', 'TYPELE', 'AMOUNT', 'REVENUE', 'UNITPRICE',
       'CREDITNOTETOTAL', 'PIPETIME', 'PIPETIMED', 'TIMEVAL', 'CREDITVAL',
       'TIMEVALSCALED', 'PIPETIMEDSCALED', 'CREDITNOTESCALED', 'AMOUNTSCALED',
       'CREDITVALSCALED', 'CNLABEL', 'CLUSTER', 'WEEK'])

# %%
bas.columns

# %%
jupyter nbconvert --to interact a_notebook.ipynb
